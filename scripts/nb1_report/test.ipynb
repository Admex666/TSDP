# %%
sample_data = {
        "league_name": "Premier League",
        "season": "2024/25",
        "round_number": 10,
        "date_range": {
            "start": "2024-11-02",
            "end": "2024-11-04"
        },
        "logo_path": "assets/premier_league_logo.png",
        
        "teams": [
            {
                "team_id": "mci",
                "team_name": "Manchester City",
                "position": 1,
                "position_history": [2, 1, 1, 1],
                "matches_played": 10,
                "wins": 7,
                "draws": 2,
                "losses": 1,
                "points": 23,
                "goals_for": 25,
                "goals_against": 8,
                "goal_difference": 17,
                "xg_total": 23.5,
                "xga_total": 7.2,
                "last_5_results": "WWDWW",
                "last_5_points": 13
            },
            {
                "team_id": "ars",
                "team_name": "Arsenal",
                "position": 2,
                "position_history": [1, 2, 2, 2],
                "matches_played": 10,
                "wins": 6,
                "draws": 3,
                "losses": 1,
                "points": 21,
                "goals_for": 22,
                "goals_against": 10,
                "goal_difference": 12,
                "xg_total": 20.8,
                "xga_total": 9.5,
                "last_5_results": "WDWDW",
                "last_5_points": 11
            },
            {
                "team_id": "liv",
                "team_name": "Liverpool",
                "position": 3,
                "position_history": [3, 3, 4, 3],
                "matches_played": 10,
                "wins": 6,
                "draws": 2,
                "losses": 2,
                "points": 20,
                "goals_for": 21,
                "goals_against": 12,
                "goal_difference": 9,
                "xg_total": 19.2,
                "xga_total": 11.8,
                "last_5_results": "WLWWD",
                "last_5_points": 10
            },
            {
                "team_id": "che",
                "team_name": "Chelsea",
                "position": 4,
                "position_history": [5, 4, 3, 4],
                "matches_played": 10,
                "wins": 5,
                "draws": 3,
                "losses": 2,
                "points": 18,
                "goals_for": 19,
                "goals_against": 13,
                "goal_difference": 6,
                "xg_total": 17.5,
                "xga_total": 13.2,
                "last_5_results": "DWWDW",
                "last_5_points": 10
            },
            {
                "team_id": "mun",
                "team_name": "Manchester United",
                "position": 14,
                "position_history": [12, 13, 14, 14],
                "matches_played": 10,
                "wins": 3,
                "draws": 2,
                "losses": 5,
                "points": 11,
                "goals_for": 12,
                "goals_against": 17,
                "goal_difference": -5,
                "xg_total": 14.8,
                "xga_total": 15.2,
                "last_5_results": "LLWDL",
                "last_5_points": 4
            },
        ],
        
        "matches": [
            {
                "match_id": "m101",
                "date": "2024-11-02",
                "home_team": "Manchester City",
                "away_team": "Arsenal",
                "home_goals": 2,
                "away_goals": 1,
                "home_xg": 1.8,
                "away_xg": 1.2,
                "home_shots": 15,
                "away_shots": 10,
                "home_possession": 58,
                "away_possession": 42
            },
            {
                "match_id": "m102",
                "date": "2024-11-02",
                "home_team": "Liverpool",
                "away_team": "Chelsea",
                "home_goals": 1,
                "away_goals": 1,
                "home_xg": 2.1,
                "away_xg": 0.9,
                "home_shots": 18,
                "away_shots": 8,
                "home_possession": 62,
                "away_possession": 38
            },
            {
                "match_id": "m103",
                "date": "2024-11-03",
                "home_team": "Manchester United",
                "away_team": "West Ham",
                "home_goals": 0,
                "away_goals": 2,
                "home_xg": 0.8,
                "away_xg": 2.3,
                "home_shots": 9,
                "away_shots": 14,
                "home_possession": 48,
                "away_possession": 52
            }
        ],
        
        "next_round_fixtures": [
            {
                "fixture_id": "f111",
                "date": "2024-11-09",
                "home_team": "Arsenal",
                "away_team": "Liverpool",
                "home_position": 2,
                "away_position": 3,
                "difficulty_rating": 8.5,
                "description": "Tabellaszomszédok csatája - Bajnoki Liga helyért"
            },
            {
                "fixture_id": "f112",
                "date": "2024-11-09",
                "home_team": "Chelsea",
                "away_team": "Manchester City",
                "home_position": 4,
                "away_position": 1,
                "difficulty_rating": 9.0,
                "description": "Címvédő elleni rangadó"
            },
            {
                "fixture_id": "f113",
                "date": "2024-11-10",
                "home_team": "Manchester United",
                "away_team": "Leicester",
                "home_position": 14,
                "away_position": 16,
                "difficulty_rating": 6.0,
                "description": "Bennmaradási harc"
            }
        ]
    }

# %% [markdown]
# # Meta: league, season, round_number, date_range, logo_path

# %%
import os 
from pathlib import Path 
import sys 

wd = Path(os.getcwd())
root = wd.parents[1]
sys.path.append(f"{root}/modules")

from SofaScore_module import scrape_sofascore

tour_id = 187 # Fizz Liga
season_id = 76944

url_stand = f"https://www.sofascore.com/api/v1/unique-tournament/{tour_id}/season/{season_id}/standings/total"
stand = scrape_sofascore(url_stand)['standings'][0]

# %%
for k, v in stand.items():
    print(f"{k}: {v}")
# Out:
# type: total
# descriptions: []
# tieBreakingRule: {'text': 'In the event that two (or more) teams have an equal number of points, the following rules break the tie:\n\n1. Number of victories\n2. Goal difference\n3. Goals scored', 'id': 1347}
# rows: [{'team': {'name': 'Debreceni VSC', 'slug': 'debreceni-vsc', 'shortName': 'Debreceni VSC', 'gender': 'M', 'sport': {'name': 'Football', 'slug': 'football', 'id': 1}, 'userCount': 7608, 'nameCode': 'DEB', 'disabled': False, 'national': False, 'type': 0, 'id': 1921, 'country': {'alpha2': 'HU', 'alpha3': 'HUN', 'name': 'Hungary', 'slug': 'hungary'}, 'teamColors': {'primary': '#cc0000', 'secondary': '#cc0000', 'text': '#cc0000'}, 'fieldTranslations': {'nameTranslation': {'ar': 'ديبرشيني', 'ru': 'ФК Дебрецен', 'hi': 'डेबरसेनी वीएससी', 'bn': 'ডেব্রেসেনি ভিএসসি'}, 'shortNameTranslation': {'ar': 'ديبريسيني في إس سي'}}}, 'descriptions': [], 'promotion': {'text': 'Champions League Qualification', 'id': 24}, 'position': 1, 'matches': 14, 'wins': 7, 'scoresFor': 22, 'scoresAgainst': 19, 'id': 1635475, 'losses': 3, 'draws': 4, 'points': 25, 'scoreDiffFormatted': '+3'}, {'team': {'name': 'Paksi FC', 'slug': 'paksi-fc', 'shortName': 'Paks', 'gender': 'M', 'sport': {'name': 'Football', 'slug': 'football', 'id': 1}, 'userCount': 19691, 'nameCode': 'PAK', 'disabled': False, 'national': False, 'type': 0, 'id': 6059, 'country': {'alpha2': 'HU', 'alpha3': 'HUN', 'name': 'Hungary', 'slug': 'hungary'}, 'teamColors': {'primary': '#006633', 'secondary': '#006633', 'text': '#006633'}, 'fieldTranslations': {'nameTranslation': {'ar': 'نادي كرة القدم پاكسي', 'ru': 'ФК Пакш', 'hi': 'पाक्सी एसए'}, 'shortNameTranslation': {}}}, 'descriptions': [], 'promotion': {'text': 'Conference League Qualification', 'id': 503}, 'position': 2, 'matches': 14, 'wins': 6, 'scoresFor': 32, 'scoresAgainst': 23, 'id': 1635483, 'losses': 2, 'draws': 6, 'points': 24, 'scoreDiffFormatted': '+9'}, {'team': {'name': 'Ferencváros TC', 'slug': 'ferencvaros-tc', 'shortName': 'Ferencváros', 'gender': 'M', 'sport': {'name': 'Football', 'slug': 'football', 'id': 1}, 'userCount': 97585, 'nameCode': 'FTC', 'disabled': False, 'national': False, 'type': 0, 'id': 1925, 'country': {'alpha2': 'HU', 'alpha3': 'HUN', 'name': 'Hungary', 'slug': 'hungary'}, 'teamColors': {'primary': '#339900', 'secondary': '#ffffff', 'text': '#ffffff'}, 'fieldTranslations': {'nameTranslation': {'ar': 'فيرينتسفاروش تي سي', 'ru': 'Ференцварош'}, 'shortNameTranslation': {'ar': 'فيرينتسفاروش', 'hi': 'फेरेन्कवरोस', 'bn': 'ফেরেনকাভারস'}}}, 'descriptions': [], 'promotion': {'text': 'Conference League Qualification', 'id': 503}, 'position': 3, 'matches': 13, 'wins': 6, 'scoresFor': 28, 'scoresAgainst': 16, 'id': 1635478, 'losses': 3, 'draws': 4, 'points': 22, 'scoreDiffFormatted': '+12'}, {'team': {'name': 'Puskás Akadémia', 'slug': 'puskas-akademia', 'shortName': 'P. Akadémia', 'gender': 'M', 'sport': {'name': 'Football', 'slug': 'football', 'id': 1}, 'userCount': 15677, 'nameCode': 'PUS', 'disabled': False, 'national': False, 'type': 0, 'id': 25596, 'country': {'alpha2': 'HU', 'alpha3': 'HUN', 'name': 'Hungary', 'slug': 'hungary'}, 'teamColors': {'primary': '#1a2948', 'secondary': '#fff200', 'text': '#fff200'}, 'fieldTranslations': {'nameTranslation': {'ar': 'بوشكاش أكاديميا', 'ru': 'Академия Пушкаш'}, 'shortNameTranslation': {'ar': 'ب. أكاديميا', 'hi': 'पुस्कस', 'bn': 'পুস্কাস'}}}, 'descriptions': [], 'position': 4, 'matches': 14, 'wins': 6, 'scoresFor': 20, 'scoresAgainst': 18, 'id': 1635484, 'losses': 4, 'draws': 4, 'points': 22, 'scoreDiffFormatted': '+2'}, {'team': {'name': 'MTK Budapest', 'slug': 'mtk-budapest', 'shortName': 'MTK', 'gender': 'M', 'sport': {'name': 'Football', 'slug': 'football', 'id': 1}, 'userCount': 7968, 'nameCode': 'MTK', 'disabled': False, 'national': False, 'type': 0, 'id': 1915, 'country': {'alpha2': 'HU', 'alpha3': 'HUN', 'name': 'Hungary', 'slug': 'hungary'}, 'teamColors': {'primary': '#2a62b9', 'secondary': '#ffffff', 'text': '#ffffff'}, 'fieldTranslations': {'nameTranslation': {'ar': 'النادى الرياضي بودپيست MTK', 'ru': 'МТК Будапешт', 'hi': 'एम्टीके बुडापेस्ट'}, 'shortNameTranslation': {}}}, 'descriptions': [], 'position': 5, 'matches': 14, 'wins': 6, 'scoresFor': 28, 'scoresAgainst ...
# id: 178579
# tournament: {'name': 'NB I', 'slug': 'nb-i', 'category': {'name': 'Hungary', 'slug': 'hungary', 'sport': {'name': 'Football', 'slug': 'football', 'id': 1}, 'id': 11, 'country': {'alpha2': 'HU', 'alpha3': 'HUN', 'name': 'Hungary', 'slug': 'hungary'}, 'flag': 'hungary', 'alpha2': 'HU', 'fieldTranslations': {'nameTranslation': {'ar': 'هنغاريا'}, 'shortNameTranslation': {}}}, 'uniqueTournament': {'name': 'Fizz Liga', 'slug': 'nb-i', 'primaryColorHex': '#006f51', 'secondaryColorHex': '#7abf43', 'category': {'name': 'Hungary', 'slug': 'hungary', 'sport': {'name': 'Football', 'slug': 'football', 'id': 1}, 'id': 11, 'country': {'alpha2': 'HU', 'alpha3': 'HUN', 'name': 'Hungary', 'slug': 'hungary'}, 'flag': 'hungary', 'alpha2': 'HU', 'fieldTranslations': {'nameTranslation': {'ar': 'هنغاريا'}, 'shortNameTranslation': {}}}, 'userCount': 11000, 'hasPerformanceGraphFeature': True, 'id': 187, 'country': {}, 'displayInverseHomeAwayTeams': False, 'fieldTranslations': {'nameTranslation': {'ar': 'الدوري المجري الممتاز', 'hi': 'एनबी I', 'bn': 'এনবি 1'}, 'shortNameTranslation': {}}}, 'priority': 4, 'isGroup': False, 'isLive': False, 'id': 50, 'fieldTranslations': {'nameTranslation': {'ar': 'الدوري المجري الممتاز', 'hi': 'एनबी I', 'bn': 'এনবি আই'}, 'shortNameTranslation': {}}}
# name: NB I 25/26
# updatedAtTimestamp: 1750145155

# %%
# Matches

round = 13
url_matches = f"https://www.sofascore.com/api/v1/unique-tournament/{tour_id}/season/{season_id}/events/round/{round}"

matches = scrape_sofascore(url_matches)

# %%
for event in matches['events']:
    event

# %%
event.keys()
# Out:
# dict_keys(['correctAiInsight', 'correctHalftimeAiInsight', 'tournament', 'season', 'roundInfo', 'customId', 'status', 'winnerCode', 'homeTeam', 'awayTeam', 'homeScore', 'awayScore', 'time', 'changes', 'hasGlobalHighlights', 'hasEventPlayerStatistics', 'hasEventPlayerHeatMap', 'detailId', 'crowdsourcingDataDisplayEnabled', 'id', 'varInProgress', 'slug', 'startTimestamp', 'finalResultOnly', 'feedLocked', 'isEditor'])

# %%
print(f"{event['homeTeam']['shortName']} vs {event['awayTeam']['shortName']}\n{event['homeScore']['display']} : {event['awayScore']['display']}")
# Out:
# Nyíregyháza vs P. Akadémia
# 1 : 1

# %%
# league
print(stand['tournament']['uniqueTournament']['name'])

# season 
season = stand['name'].split(' ')[-1]
print(season)

# round_number 
matches_max = 0
for row in stand['rows']:
    if row['matches'] > matches_max:
        matches_max = row['matches']
print(matches_max)

# date_range 

# logo_path
print(f"https://img.sofascore.com/api/v1/unique-tournament/{tour_id}/image")
# Out:
# Fizz Liga
# 25/26
# 14
# https://img.sofascore.com/api/v1/unique-tournament/187/image

# %% [markdown]
# # Teams

# %%
# team_id: mci
# team_name: Manchester City
# position: 1
# position_history: [2, 1, 1, 1]
# matches_played: 10
# wins: 7
# draws: 2
# losses: 1
# points: 23
# goals_for: 25
# goals_against: 8
# goal_difference: 17
# xg_total: 23.5
# xga_total: 7.2
# last_5_results: WWDWW
# last_5_points: 13

# %% [markdown]
# # Matches

# %%
# match_id: m101
# date: 2024-11-02
# home_team: Manchester City
# away_team: Arsenal
# home_goals: 2
# away_goals: 1
# home_xg: 1.8
# away_xg: 1.2
# home_shots: 15
# away_shots: 10
# home_possession: 58
# away_possession: 42

# %% [markdown]
# # Next Round Fixtures

# %%
# fixture_id: f111
# date: 2024-11-09
# home_team: Arsenal
# away_team: Liverpool
# home_position: 2
# away_position: 3
# difficulty_rating: 8.5
# description: Tabellaszomszédok csatája - Bajnoki Liga helyért

# %%
import soccerdata as sd

season = 2023

fbref = sd.FBref(leagues="ENG-Premier League", seasons=season)

team_match_stats = fbref.read_team_match_stats(stat_type="schedule", team="Manchester City")
team_match_stats.head()
# Out:
# [01/09/26 16:03:07] INFO     Saving cached data to C:\Users\Adam\soccerdata\data\FBref               ]8;id=719825;file://e:\anacoda3\Lib\site-packages\soccerdata\_common.py\_common.py]8;;\:]8;id=127253;file://e:\anacoda3\Lib\site-packages\soccerdata\_common.py#263\263]8;;\
#                     WARNING  e:\anacoda3\Lib\site-packages\soccerdata\fbref.py:165: FutureWarning:  ]8;id=194501;file://e:\anacoda3\Lib\warnings.py\warnings.py]8;;\:]8;id=835139;file://e:\anacoda3\Lib\warnings.py#112\112]8;;\
#                              The behavior of DataFrame concatenation with empty or all-NA entries
#                              is deprecated. In a future version, this will no longer exclude empty
#                              or all-NA columns when determining the result dtypes. To retain the
#                              old behavior, exclude the relevant entries before the concat
#                              operation.
#                                pd.concat(dfs)
# ...

# %%
print(fbref.__doc__)
# Out:
# Provides pd.DataFrames from data at http://fbref.com.
#
#     Data will be downloaded as necessary and cached locally in
#     ``~/soccerdata/data/FBref``.
#
#     Parameters
#     ----------
#     leagues : string or iterable, optional
#         IDs of leagues to include. For efficiently reading data from the Top-5
#         European leagues, use "Big 5 European Leagues Combined".
#     seasons : string, int or list, optional
#         Seasons to include. Supports multiple formats.
#         Examples: '16-17'; 2016; '2016-17'; [14, 15, 16]
#     proxy : 'tor' or dict or list(dict) or callable, optional
#         Use a proxy to hide your IP address. Valid options are:
#             - "tor": Uses the Tor network. Tor should be running in
#               the background on port 9050.
#             - dict: A dictionary with the proxy to use. The dict should be
#               a mapping of supported protocols to proxy addresses. For example::
#
#                   {
# ...

# %%
match_id = "0b8f50a5"

player_match_stats = fbref.read_player_match_stats(stat_type="passing", match_id=match_id)
display(player_match_stats)

lineups = fbref.read_lineup(match_id=match_id)
display(lineups)
# Out:
# [01/09/26 16:02:54] WARNING  e:\anacoda3\Lib\site-packages\soccerdata\fbref.py:165: FutureWarning:  ]8;id=636330;file://e:\anacoda3\Lib\warnings.py\warnings.py]8;;\:]8;id=559448;file://e:\anacoda3\Lib\warnings.py#112\112]8;;\
#                              The behavior of DataFrame concatenation with empty or all-NA entries
#                              is deprecated. In a future version, this will no longer exclude empty
#                              or all-NA columns when determining the result dtypes. To retain the
#                              old behavior, exclude the relevant entries before the concat
#                              operation.
#                                pd.concat(dfs)
# [01/09/26 16:02:55] INFO     [1/1] Retrieving game with id=0b8f50a5                                    ]8;id=931695;file://e:\anacoda3\Lib\site-packages\soccerdata\fbref.py\fbref.py]8;;\:]8;id=835090;file://e:\anacoda3\Lib\site-packages\soccerdata\fbref.py#815\815]8;;\
# ...
